# %%
# Import library yang diperlukan
import pandas as pd               # manipulasi data
import numpy as np                # operasi numerik
import matplotlib.pyplot as plt   # visualisasi
import seaborn as sns             # visualisasi tambahan

# %%
# ============================
# 1. Memuat Dataset Titanic
# ============================
data_titanic = sns.load_dataset("titanic")

# Menampilkan 5 baris pertama dataset
print("5 Baris Pertama Dataset Titanic:")
print(data_titanic.head())
# Out:
# 5 Baris Pertama Dataset Titanic:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# ============================
# 2. Modifikasi Kolom
# ============================
# Buat kolom baru 'gender_num' (male=1, female=0)
data_titanic['gender_num'] = data_titanic['sex'].map({'male': 1, 'female': 0})
print("\nContoh kolom gender_num:")
print(data_titanic[['sex', 'gender_num']].head())
# Out:
# Contoh kolom gender_num:
#       sex  gender_num
# 0    male           1
# 1  female           0
# 2  female           0
# 3  female           0
# 4    male           1

# %%
# ============================
# 3. Statistik Deskriptif
# ============================
print("\nInformasi Dataset:")
print(data_titanic.info())

print("\nStatistik Deskriptif:")
print(data_titanic.describe())
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  gender_num   891 non-null    int64
# dtypes: bool(2), category(2), float64(2), int64(5), object(5)
# memory usage: 87.6+ KB
# None
#
# ...

# %%
# ============================
# 4. Analisis Missing Values
# ============================
missing_counts = data_titanic.isnull().sum()
print("\nJumlah Missing Values per Kolom:")
print(missing_counts)

# Visualisasi missing values
plt.figure(figsize=(10,5))
sns.heatmap(data_titanic.isnull(), cbar=False, cmap="viridis")
plt.title("Visualisasi Missing Values")
plt.show()
# Out:
# Jumlah Missing Values per Kolom:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# gender_num       0
# dtype: int64

# %%
# ============================
# 5. Visualisasi Data
# ============================

# a) Distribusi Umur Penumpang
plt.figure(figsize=(8,5))
sns.histplot(data_titanic['age'], bins=30, kde=True, color="skyblue")
plt.title("Distribusi Umur Penumpang")
plt.xlabel("Umur")
plt.ylabel("Jumlah Penumpang")
plt.show()

# b) Perbandingan Tarif (fare) berdasarkan Kelas
plt.figure(figsize=(8,5))
sns.boxplot(x="class", y="fare", data=data_titanic, palette="Set2")
plt.title("Perbandingan Tarif berdasarkan Kelas")
plt.xlabel("Kelas")
plt.ylabel("Tarif")
plt.show()

#Analisis Tingkat Kelangsungan Hidup Berdasarkan Kelas Penumpang
plt.figure(figsize=(10, 6))
sns.barplot(x='pclass', y='survived', data=data_titanic, palette='Set2')
plt.title('Tingkat Kelangsungan Hidup Berdasarkan Kelas Penumpang')
plt.xlabel('Kelas Penumpang (1 = Pertama, 2 = Kedua, 3 = Ketiga)')
plt.ylabel('Tingkat Kelangsungan Hidup')
plt.xticks([0, 1, 2], ['Kelas 1', 'Kelas 2', 'Kelas 3'])
plt.show()

# c) Tingkat Kelangsungan Hidup berdasarkan Jenis Kelamin
plt.figure(figsize=(8,5))
sns.barplot(x="sex", y="survived", data=data_titanic, palette="pastel")
plt.title("Tingkat Kelangsungan Hidup berdasarkan Jenis Kelamin")
plt.xlabel("Jenis Kelamin")
plt.ylabel("Proporsi Selamat")
plt.show()

# d) Hubungan Umur dan Tarif dengan Warna berdasarkan Survival
plt.figure(figsize=(8,5))
sns.scatterplot(x="age", y="fare", hue="survived", data=data_titanic, palette="coolwarm", alpha=0.7)
plt.title("Hubungan Umur dan Tarif terhadap Kelangsungan Hidup")
plt.xlabel("Umur")
plt.ylabel("Tarif")
plt.show()

# e) Analisis Tingkat Kelangsungan Hidup: Sendiri vs. Bersama Keluarga
plt.figure(figsize=(8, 6))
sns.barplot(x='alone', y='survived', data=data_titanic, palette='viridis')
plt.title('Tingkat Kelangsungan Hidup: Sendiri vs. Bersama Keluarga')
plt.xlabel('Status')
plt.ylabel('Tingkat Kelangsungan Hidup')
plt.xticks([0, 1], ['Bersama Keluarga', 'Sendiri'])
plt.show()
# Out:
# /tmp/ipython-input-3821255896.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="fare", data=data_titanic, palette="Set2")
# /tmp/ipython-input-3821255896.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='pclass', y='survived', data=data_titanic, palette='Set2')
# /tmp/ipython-input-3821255896.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sex", y="survived", data=data_titanic, palette="pastel")
# /tmp/ipython-input-3821255896.py:48: FutureWarning:
#
# ...
